# %% [markdown]
# <a href="https://colab.research.google.com/github/Liliansampaioleite/AED1/blob/main/Aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ord("z")
# Out:
# 122

# %%
format(65, "08b")
# Out:
# '01000001'

# %%
print(format(ord("L"), "08b"))
print(format(ord("e"), "08b"))
print(format(ord("i"), "08b"))
print(format(ord("t"), "08b"))
print(format(ord("e"), "08b"))
# Out:
# 01001100
# 01100101
# 01101001
# 01110100
# 01100101

# %%
for i in range(5):

# %%
chr(65)
# Out:
# 'A'
